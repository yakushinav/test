# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Вещественное число в формате ?#.00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +12.456, -.30, 0.60

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Время в формате ЧЧ:ММ (24-часовой)
#
#  Примеры соответствия шаблону
#
# 14:30, 09:15, 23:45

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Acarnaniae, quae antea Curetis vocabatur, oppida Hercalia, Echinus et in ore ipso colonia Augusti Actium cum templo Apollinis nobili ac civitate libera Nicopolitana. egressos sinu Ambracio in Ionium excipit Leucadium litus, promunturium Leucates, dein sinus et Leucadia ipsa paeninsula, quondam Neritis appellata, opere accolarum abscisa continenti ac reddita venturum flatu congeriem harenae adtumulantium, qui locus vocatur Dioryctos stadiorum longitudine trium. oppidum in ea Leucas, quondam Neritum dictum. deinde Acarnanum urbes Alyzia, Stratos, Argos Amphilochium cognominatum. amnis Achelous e Pindo fluens Acarnaniam ab Aetolia dirimens et Artemitam insulam adsiduo terrae invectu continenti adnectens.
#
# Aetolorum populi Athamanes, Tymphaei, Ephyri, Aenienses, Perrhaebi, Dolopes, Maraces, Atraces, a quibus Atrax amnis Ionio mari infunditur. Aetoliae oppidum Calydon est VII:D passuum a mari iuxta euenum amnem. dein Macynia, Molycria, cuius a tergo Chalcis mons et Taphiassus. at in ora promunturium Antirrhium, ubi ostium Corinthiaci sinus minus M p. latitudine influentis Aetolosque dirimentis a Peloponneso. promunturium quod contra procedit appellatur Rhion. sed in Corinthio ainu oppida Aetoliae Naupactus, Eupalimna et in mediterraneo Pleuron, Halicarna, montes clari in Dodone Tomarus, in Ambracia Crauia, in Acarnania Aracynthus, in Aetolia Achaton, Panaetolium, Macynium.

# %% [markdown]
# Шаблон для поиска: слова, содержащие три символа a
#
#  Примеры соответствия шаблону
#
# Hercalia

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате JSON:
#
# {“objectID”:”objectID”, “token”:”token”, “price”:price, “date”:”date”}
#
# - objectID содержит ID объекта недвижимости, целое число от 1000 до 9999 включительно;
# - token содержит токен операции, кодирующий создание нового элемента в цепочке сделок с объектом недвижимости набор букв английского алфавита в верхнем регистре длиной 8 символов;
# - price содержит стоимость объекта недвижимости, целое число от 500000 до 5000000 включительно;
# - date содержит дату в формате ДД/ММ/ГГГГ.

# %% [markdown]
# Примеры входных данных
#
#
# {"objectID": 1234, "token": "ABCDEFGH", "price": 1000000, "date": "01/01/2023"}
#
#
# {"objectID": 1234, "token": "ABCDEFGH", "price": 1000000, "date": "01/01/2023"}

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Adapter
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Сторонняя библиотека: Вы используете библиотеку для работы с картами, которая
# принимает координаты в формате "широта,долгота", но ваша система хранит их
# в отдельных полях. Создайте адаптер для преобразования формата данных.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Open/Closed Principle (OCP) — Принцип открытости/закрытости: Программные сущности должны быть открыты для расширения, но закрыты для модификации. Это значит, что можно добавлять новую функциональность, не меняя существующий код.

# %%
class Shape:
    def area(self):
        raise NotImplementedError("This method should be overridden by subclasses")


class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius


class AreaCalculator:
    def calculate_area(self, shape):
        return shape.area()


rectangle = Rectangle(10, 5)
circle = Circle(7)

calculator = AreaCalculator()
print(calculator.calculate_area(rectangle))  # Outputs: 50
print(calculator.calculate_area(circle))     # Outputs: 153.86

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
