# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Целое число в формате ?##0000
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +123456, -0123, 10006

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Номер телефона в международном формате: 8-XXX:XXX:XX:XX
#
#  Примеры соответствия шаблону
#
# 8-912:345:67:89, 8-495:123:45:67, 8-800:555:35:35

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Invenit tamen inter has utrasque sententias medium sibi ipsa mortalitas numen, quo minus etiam plana de deo coniectatio esset. toto quippe mundo et omnibus locis omnibusque horis omnium vocibus Fortuna sola invocatur ac nominatur, una accusatur, res una agitur, una cogitatur, sola laudatur, sola arguitur et cum conviciis colitur, volubilis . . . .que, a plerisque vero et caeca existimata, vaga, inconstans, incerta, varia indignorumque fautrix. huic omnia expensa, huic feruntur accepta, et in toto ratione mortalium sola utramque paginam facit, adeoque obnoxiae sumus sortis, ut prorsus ipsa pro deo sit qua deus probatur incertus.
#
# pars alia et hanc pellit astroque suo eventus adsignat et nascendi legibus, semelque in omnes futuros umquam deo decretum, in reliquum vero otium datum. sedere coepit sententia haec, pariterque et eruditum vulgus et rude in eam cursus vadit.
#
# ecce fulgurum monitus, oraculorum praescita, haruspicum praedicta atque etiam parva dictu in auguriis sternumenta et offensiones pedum. Divus Augustus prodidit laevum sibi calceum praepostere inductum quo die seditione militari prope adflictus est.

# %% [markdown]
# Шаблон для поиска: слова длиной 5 символов, начинающиеся на букву a
#
#  Примеры соответствия шаблону
#
# aliqu

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подаются строки с описанием запроса доставки в формате JSON в виде набора полей:
#
# {"date":"ДД/ММ/ГГГГ", "relative":"relativePattern"}
# - поле date содержит дату от которой рассчитывается дата доставки;
# - поле relative содержит один из двух относительных шаблонов relativePattern:
#     - next DayOfWeek доставка в указанный день недели относительной заданной даты, DayOfWeek содержит одно из следующих значений Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, Sunday (Понедельник, Вторник, Среда, Четверг, Пятница, Суббота, Воскресенье соответственно);
#     - +N week, доставка через N недель от текущей даты, N целое число от 1 до 9 включительно.

# %% [markdown]
# Примеры входных данных
#
#
# {"date":"29/05/2025", "relative":"next Monday"}
#
# {"date":"29/05/2025", "relative":"+1 week"}

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Factory Method
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Форматы данных: Система должна экспортировать данные в разных форматах
# (JSON, XML, CSV). Каждый формат требует своей обработки. Реализуйте фабричный метод
# для создания объектов экспортеров данных.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
class Performer:
    def __init__(self, name):
        self.name = name

    def sing(self):
        return f"{self.name} is singing a beautiful song."

    def dance(self):
        return f"{self.name} is dancing with amazing moves."


# Usage
kirby_bad = Performer("Pink Kirby")
print(kirby_bad.sing())
print(kirby_bad.dance())

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
