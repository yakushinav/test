# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Целое число в формате ?0000
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +1234, 0023, -0001

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Номер телефона в международном формате: 8(XXX)XXX-XX-XX
#
#  Примеры соответствия шаблону
#
# 8(912)345-67-89, 8(495)123-45-67, 8(800)555-35-35

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Formam eius in speciem orbis absoluti globatam esse nomen in primis et consensus in eo mortalium orbem appellantium, sed et argumenta rerum docent, non solum quia talis figura omnibus sui partibus vergit in sese ac sibi ipsa toleranda est seque includit et continet nullarum egens compagium nec finem aut initium ullis sui partibus sentiens, nec quia ad motum, quo subinde verti mox adparebit, talis aptissima est, sed oculorum quoque probatione, quod convexus mediusque quacumque cernatur, cum id accidere in alia non possit figura.
#
# Hanc ergo formam eius aeterno et inrequieto ambitu, inenarrabili celeritate, viginti quattuor horarum spatio circumagi solis exortus et occasus haut dubium reliquere. an sit inmensus et ideo sensum aurium excedens tantae molis rotatae vertigine adsidua sonitus, non equidem facile dixerim, non, Hercule, magis quam circumactorum simul tinnitus siderum suosque volventium orbes an dulcis quidam et incredibili suavitate concentus. nobis qui intus agimus iuxta diebus noctibusque tacitus labitur mundus.

# %% [markdown]
# Шаблон для поиска: слова длиной 6 символов
#
#  Примеры соответствия шаблону
#
# Formam

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается JSON в следующем формате
#
#
# {"productId": productID, "category": "categoryName", "price": price, "quantity": quantity}
# - productID содержит ID товара, целое число в формате от 10000 до 99999 включительно;
# - category содержит имя категории, набор символов английского алфавита в нижнем регистре длиной от 3 до 40 символов включительно;
# - price содержит цену товара, целое число от 1 до 10000 включительно;
# - quantity содержит количество товара, целое число от 1 до 500 включительно.

# %% [markdown]
# Примеры входных данных
#
#
# {"productId": 12345, "category": "electronics", "price": 1000, "quantity": 5}
#
#
# {"productId": 67890, "category": "clothing", "price": 500, "quantity": 2}
#
#
# {"productId": 11111, "category": "books", "price": 200, "quantity": 10}

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Factory Method
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Генератор документов: Программа должна создавать разные типы документов
# (отчет, письмо, справка). Каждый тип документа имеет свой формат и набор полей.
# Реализуйте фабричный метод для создания объектов документов.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
class Invoice:
    """
    A representation of an invoice.
    """

    def __init__(self, recipient: str, total: float) -> None:
        self.recipient = recipient
        self.total = total

    def send(self) -> None:
        print(f"Sending invoice in an email to: {self.recipient}")


class OrderManager:

    def __init__(self, price: float, recipient: str) -> None:
        self.price = price
        self.recipient = recipient

    def calculate_discount(self) -> float:

        if self.recipient == "tenpercent@foobar.com":
            return self.price / 100 * 10
        elif self.recipient == "fiftypercent@foobar.com":
            return self.price / 100 * 50
        return self.price

    def dispatch_invoice(self) -> Invoice:
        invoice = Invoice(self.recipient, self.calculate_discount())
        invoice.send()
        return invoice

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
