# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Научный формат +0000E+00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +0250E+30, -1250E-30, -1251E+00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Отрезок в формате [a,b] (a и b - действительные числа)
#
#  Примеры соответствия шаблону
#
# [1,5], [-3.14,2.71], [0,100]

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Ortus hic in Germania iugis montis Abnouae ex adverso Raurici Galliae oppidi, multis ultra Alpes milibus ac per innumeras lapsus gentes Danuvi nomine, inmenso aquarum auctu et unde primum Illyricum adluit Hister appellatus, LX amnibus receptis, medio ferme eorum numero navigabili, in Pontum vastis sex fluminibus evolvitur. primum ostium Peuces, mox ipsa Peuce insula, in qua proximus alveus appellatus XIX p. magna palude sorbetur. ex eodem alveo et super Histropolim lacus gignitur LXIII passuum ambitu; Halmyrin vocant. secundum ostium Naracustoma appellatur, tertium Calon Stoma iuxta insulam Sarmaticam, quartum Pseudostomon et insula Conopon Diabasis, postea Borion Stoma et Psilon Stoma. singula autem ora sunt tanta, ut prodatur in XL passuum longitudinis vinci mare dulcemque intellegi haustum.
# Ab eo in plenum quidem omnes Scytharum sunt gentes, varie tamen litori adposita tenuere, alias Getae, Daci Romanis dicti, alias Sarmatae, Graecis Sauromatae, eorumque Hamaxobli aut Aorsi, alias Scythae degeneres et a servis orti aut Trogodytae, mox Alani et Rhoxolani; superiora autem inter Danuvium et Hercynium saltum usque ad Pannonica hiberna Carnunti Germanorumque ibi confinium, campos et plana Iazyges Sarmatae, montes vero et saltus pulsi ab iis Daci ad Pathissum amnem, 81 a Maro, sive Duria est a Suebis regnoque Vanniano dirimens eos, aversa Basternae tenent aliique inde Germani.grippa totum eum tractum ab Histro ad oceanum bis ad decies centenum milium passuum in longitudinem, quattuor milibus minus CCCC in latitudinem, ad flumen Vistlam a desertis Sarmatiae prodidit. Scytharum nomen usquequaque transiit in Sarmatas atque Germanos. nec aliis prisca illa duravit appellatio quam qui extremi gentium harum, ignotic prope ceteris mortalibus, degunt.

# %% [markdown]
# Шаблон для поиска: слова длиной больше 6 символов, начинающиеся на букву f
#
#  Примеры соответствия шаблону
#
# fugiatq

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате CSV с разделителем полей '::':
#
#
# username::password
# - поле username это имя пользователя, набор символов английского алфавита, цифр длиной от 5 до 20 символов включительно;
# - password это пароль пользователя, набор символов английского алфавита, цифр, специальных символов длиной от 8 до 14 символов включительно.
#
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# username1::password123
#
#
# validUser  ::  sTr0ngP@ss

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Observer
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Погодная станция: При изменении температуры, влажности и давления
# несколько дисплеев (текущие условия, статистика, прогноз) должны автоматически обновляться.
# Реализуйте наблюдателей для дисплеев.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Liskov Substitution Principle (LSP) — Принцип подстановки Барбары Лисков: Объекты в программе должны быть заменяемыми на экземпляры их подтипов без изменения корректности выполнения программы.

# %%
class BadParentKirby:
    def introduce(self):
        return "I'm parent Kirby"

    def make_coffee(self):
        return "I make coffee"


class BadChildKirby(BadParentKirby):
    def introduce(self):
        return "I'm child Kirby"

    def make_coffee(self):
        return "No but do you want tea instead?"


print("BAD EXAMPLE - LSP Violation:")
parent = BadParentKirby()
child = BadChildKirby()

print(f"Parent: {parent.introduce()} & {parent.make_coffee()}")
print(f"Child: {child.introduce()}")

print("\nParent's coffee request:")
print(f"- Can you make me coffee? - {parent.make_coffee()}")

print("\nChild's coffee request:")
print(f"- Can you make me coffee? - {child.make_coffee()}")
print("- Ugh you violated LSP")
print("This is a bad example because ChildKirby cannot replace ParentKirby!")

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
