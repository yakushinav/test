# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Вещественное число в формате ?0.00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +12.456, -0.30, 6.00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Дата в формате ГГГГ-ММ-ДД
#
#  Примеры соответствия шаблону
#
# 2023-12-31, 2000-01-01, 2025-08-15

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Baetis, in Tarraconensis provinciae non, ut aliqui dixere, Mentesa oppido, sed Tugiensi exoriens saltu — iuxta quem Tader fluvius, qui Carthaginiensem agrum rigat — Ilorci refugit Scipionis rogum versusque in occasum oceanum Atlanticum, provinciam adoptans, petit, modicus primo, sed multorum fluminum capax, quibus ipse famam aquasque aufert. Baeticae primum ab Ossigitania infusus, amoeno blandus alveo, crebris dextra laevaque accolitur oppidis.
#
# Celeberrima inter hunc et oceani oram in mediterraneo Segida quae Augurina cognominatur, Ulia quae Fidentia, Urgao quae Alba, Ebora quae Cerialis, Iliberri quod Iliberini, Ilipula quae Laus, Artigi quod Iulienses, Vesci quod Faventia, Singili, Ategua, Arialdunum, Agla Minor, Baebro, Castra Vinaria, Cisimbrium, Hippo Nova, Ilurco, Osca, Oscua, Sucaelo, Unditanum, Tucci Vetus, omnia Bastetaniae vergentis ad mare. conventus vero Cordubensis circa flumen ipsum Ossigi quod cognominatur Latonium, Iliturgi quod Forum Iulium, Ipra, Isturgi quod Triumphales, Ucia et XIIII p. remotum in mediterraneo Obulco quod Pontificense appellatur, mox Ripa, Epora foederatorum, Sacili Martialium, Onuba et dextra Corduba colonia Patricia cognomine, inde primum navigabili Baete oppida Carbula, Detumo, fluvius Singilis, eodem Baetis latere incidens.

# %% [markdown]
# Шаблон для поиска: слова длиной 6 символов, заканчивающиеся на букву f
#
#  Примеры соответствия шаблону
#
# deserf

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате JSON:
#
# {“taxiID”:taxiID, “class”:”taxiClass”, “model”:”taxiModel”, “hours”:workingHowrs}
# - taxiID содержит ID такси, целое число от 1000 до 9999 включительно;
# - class содержит класс такси, одна буква английского алфавита A,B,C,D,E;
# - model содержит модель автомобиля такси, набор символов английского алфавита длиной от 3 до 15 символов;
# - hours содержит установленное время выхода на линию в формате ЧЧ:ММ, которое является стандартным временем ЧЧ от 00 до 23, ММ от 00 до 59.

# %% [markdown]
# Примеры входных данных
#
#
# {"taxiID":1234, "class":"A", "model":"ToyotaCamry", "hours":"08:30"}
#
# {"taxiID": 5678, "class" : "B", "model": "HondaAccord", "hours": "12:45"}

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Abstract Factory
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Операционные системы: Система для работы с файлами и процессами.
# Для каждой ОС (Windows, Unix) нужны свои реализации файлового менеджера и диспетчера задач.
# Создайте абстрактную фабрику для создания этих компонентов.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
class Account:
    """Demo bank account class """

    def __init__(self, account_no: str):
        self.account_no = account_no

    def get_account_number(self):
        """Get account number"""
        return self.account_no

    def save(self):
        """Save account number into DB"""
        pass

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
