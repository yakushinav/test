# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Вещественное число в формате +#.00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +12.456, -.30, +0.60

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Дата в формате ММ/ДД/ГГГГ
#
#  Примеры соответствия шаблону
#
# 12/31/2023, 01/01/2000, 08/15/2025

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Tertius Europae sinus Acrocerauniis incipit montibus, finitur Hellesponto, amplectitur praeter minores sinus |XIX|:XXV passuum. in eo Epirus, Acarnania, Aetolia, Phocis, Locris, Achaia, Messenia, Laconica, Argolis, Megaris, Attice, Boeotia iterumque ab ealio mari eadem Macedonia, Thracia. omnis Graeciae fabulositas sicut et litterarum claritas ex hoc primum sinu effulsit, quapropter paululum in eo conmorabimur.
#
# Epiros in universum appellata a Cerauniis incipit montibus. in ea primi Chaones, a quibus Chaonia, dein Thesproti, Antigonenses, locus Aornos et pestifera avibus exhalatio, Cestrini, Perrhaebi, quorum mons Pindus, Cassopaei, Dryopes, Selloe, Hellopes, Molossi, apud quos Dodonaei Iovis templum oraculo inlustre, Talarus mons, centum fontibus circa radices Theopompo celebratus. 3 Epiros ipsa, ad Magnesiam Macedoniamque tendens, a tergo suo Dassaretas supra dictos, liberam gentem, mox feram Dardanos habet. Dardanis laevo Triballi praetendentur latere et Moesicae gentes, a fronte iunguntur Maedi ac Denselatae, quibus Threces ad Pontum usque pertinentes. ita succincta Rhodopes, mox et Haemi, vallatur excelsitas. 4 in Epiri ora castellum in Acrocerauniis Chimera, sub eo Aquae Regiae fons, oppida Maeandria, Cestria, flumen Thesprotiae Thyamis, colonia Buthrotum, maximeque nobilitatus Ambracius sinus, D passuum faucibus spatiosum aequor accipiens, longitudinis XXXVII, latitudinis XV. in eum defertur amnis Acheron, e lacu Thesprotias Acherusia profluens XXXV passuum inde et mille pedum ponte mirabilis omnia sua mirantibus. in sinu oppidum Ambracia. Molossorum flumina Aphas, Aratthus, civitas Anactorica, locus Pandosia.

# %% [markdown]
# Шаблон для поиска: слова длиной 7 символов, заканчивающиеся на букву d
#
#  Примеры соответствия шаблону
#
# voluptd

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате CSV
#
# filialID;date;category;count;price
# - filialID содержит ID филиала, целое число от 1 до 99 включительно
# - date содержит корректную дату в формате ДД-ММ-ГГГГ;
# - category содержит модель категорию товара, целое число от 100 до 999 включительно;
# - count содержит количество единиц товара, целое число от 1 до 500 включительно;
# - price содержит цену товара, целое число от 100 до 5000 включительно.
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# 1;01-01-2023;100;10;1000
#
#  2 ; 02-02-2023 ; 200 ; 20 ; 2000
#
# 3 ;15-06-2023;500;1;5000

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Adapter
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Старая система: У вас есть класс "СтарыйПринтер" с методом печати `printDocument()`,
# но новый код ожидает интерфейс с методом `print()`. Создайте адаптер, чтобы
# старый принтер мог работать с новым интерфейсом.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Open/Closed Principle (OCP) — Принцип открытости/закрытости: Программные сущности должны быть открыты для расширения, но закрыты для модификации. Это значит, что можно добавлять новую функциональность, не меняя существующий код.

# %%
from abc import ABC, abstractmethod


class Car:

    def __init__(self, fuel_type: str) -> None:
        self.fuel_type = fuel_type

    def __repr__(self) -> str:
        return f"Car(fuel_type={self.fuel_type})"


class FuelStation:  # type: ignore # noqa

    def refuel(self, car: Car) -> None:
        if car.fuel_type == "petrol":
            self._fill_with_petrol(car)
        elif car.fuel_type == "diesel":
            self._fill_with_diesel(car)
        elif car.fuel_type == "electric":
            self._fill_with_electric(car)

    @staticmethod
    def _fill_with_electric(car: Car) -> None:
        print(f"Charging {car} with electricity...")

    @staticmethod
    def _fill_with_petrol(car: Car) -> None:
        print(f"Filling {car} with petrol..")

    @staticmethod
    def _fill_with_diesel(car: Car) -> None:
        print(f"Filling {car} with diesel..")

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
