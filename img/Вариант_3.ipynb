# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Целое число в формате +##0000
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +123456, -0123, -10006

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Номер телефона в международном формате: +7-XXX-XXX-(XX-XX)
#
#  Примеры соответствия шаблону
#
# +7-912-345-(67-89), +7-495-123-(45-67), +7-800-555-(35-35)

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Quapropter effigiem dei formamque quaerere inbecillitatis humanae reor. quisquis est deus, si modo est alius, et quacumque in parte, totus est sensus, totus visus, totus auditus, totus animae, totus animi, totus sui. innumeros quidem credere atque etiam ex vitiis hominum, ut Pudicitiam, Concordiam, Mentem, Spem, Honorem, Clementiam, Fidem, aut, ut Democrito placuit, duos omnino, Poenam et Beneficium, maiorem ad socordiam accedit.
#
# fragilis et laboriosa mortalitas in partes ita digessit infirmitatis suae memor, ut portionibus coleret quisque quo maxime indigeret. itaque nomina alia aliis gentibus et numina in iisdem innumerabilia invenimus, inferis quoque in genera discriptis morbisque et multis etiam pestibus, dum esse placatas trepido metu cupimus.

# %% [markdown]
# Шаблон для поиска: слова длиной 7 символов
#
#  Примеры соответствия шаблону
#
# adipisc

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в следующем формате
#
# userID|first_name|last_name|summa|country
# - поле userID cодержит ID клиента, целое число в формате от 10000 до 99999 включительно
# - first_name содержит имя клиента, набор символов английского алфавита длиной от 3 до 40 символов включительно
# - last_name содержит фамилию клиента, набор символов английского алфавита длиной от 1 до 50 символов включительно (комбинация first_name и last_name уникальна для клиента)
# - summa содержит сумму выкупа клиента, целое число от 1000 до 100000 включительно
# - country содержит страну клиента, набор символов английского алфавита длиной от 3 до 100 символов включительно

# %% [markdown]
# Примеры входных данных
#
#
# 20001| Michael | Jordan | 45000 | usa
#
# 20002|  Leo  |  Messi  | 350000 | Argentina
#
# 20003|Sergey|Ivanov|2000|RUSSIA
#
# 20004| Anna | Karenina | 28000 | Russia
#
# 20005| Peter | Parker | 160000 | USA

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Factory Method
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Игра: Создание персонажей. В зависимости от выбранного класса (воин, маг, лучник)
# создаются разные объекты персонажей с уникальными характеристиками и способностями.
# Реализуйте фабричный метод для создания персонажей.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
class UserManager:
    def __init__(self):
        self.users = []

    def add_user(self, user):
        self.users.append(user)
        self.send_notification(user)

    def send_notification(self, user):
        print(f"Notification: User {user} has been added.")

    def get_users(self):
        return self.users


if __name__ == "__main__":
    user_manager = UserManager()
    user_manager.add_user("Alice")
    user_manager.add_user("Bob")
    print(user_manager.get_users())

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
