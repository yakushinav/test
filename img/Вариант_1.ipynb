# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Целое число в формате +0000
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +1234, -0023, +0001

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Номер телефона в международном формате: +7(XXX)XXX-XX-XX
#
#  Примеры соответствия шаблону
#
# +7(912)345-67-89, +7(495)123-45-67, +7(800)555-35-35

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Mundum et hoc quodcumque nomine alio caelum appellare libuit, cuius circumflexu degunt cuncta, numen esse credi par est, aeternum, inmensum, neque genitum neque interiturum umquam. huius extera indagare nec interest hominum nec capit humanae coniectura mentis.
#
# sacer est, aeternus, immensus, totus in toto, immo vero ipse totum, infinitus ac finito similis, omnium rerum certus et similis incerto, extra intra cuncta conplexus in se, idemque rerum naturae opus et rerum ipsa natura.
#
# furor est mensuram eius animo quosdam agitasse atque prodere ausos, alios rursus occasione hinc sumpta aut his data innumerabiles tradidisse mundos, ut totidem rerum naturas credi oporteret aut, si una omnes incubaret, totidem tamen soles totidemque lunas et cetera etiam in uno et inmensa et innumerabilia sidera, quasi non eaedem quaestiones semper in termino cogitationi sint occursurae desiderio finis alicuius aut, si haec infinitas naturae omnium artifici possit adsignari, non idem illud in uno facilius sit intellegi, tanto praesertim opere.

# %% [markdown]
# Шаблон для поиска: слова длиной 5 символов
#
#  Примеры соответствия шаблону
#
# totus

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# Строки в формате CSV, в виде набора полей разделенных точкой с запятой:
#
#
# dateTime;userID;pageName
# - поле dateTime содержит корректные дату и время доступа к странице в формате ДД:ММ:ГГГГ:ЧЧ:ММ;
# - поле userID, содержит корректный ID пользователя целое число от 1000 до 9999 включительно;
# - поле pageName корректное имя страницы, набор символов английского алфавита в разном регистре длиной от 4 до 100 включительно, два имени страницы считаются одинаковыми если совпадают при записи в нижнем регистре.
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# 01:01:2023:10:00; 1001 ; HomePage
#
#
# 01:01:2023:10:01; 1002 ; Login
#
#
# 01:01:2023:10:02; 1001 ; Dashboard

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Factory Method
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Система логистики: Нужно создать систему, которая выбирает способ доставки.
# В зависимости от типа груза (маленький, крупный, опасный) выбирается соответствующий
# тип транспорта: фургон для маленьких, грузовик для крупных, спецтранспорт для опасных.
# Создайте фабричный метод для создания объектов транспорта.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
class ValidatePerson:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def validate_name(self, name):
        if len(name) > 3:
            return True
        else:
            return False

    def validate_age(self, age):
        if age > 18:
            return True
        else:
            return False

    def display(self):
        if self.validate_name(self.name) and self.validate_age(self.age):
            print(f"Name: {self.name} and Age: {self.age}")
        else:
            print("Invalid")

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
