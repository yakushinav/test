# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Научный формат ?0000E+00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +0250E+30, 1250E-30, -1251E+00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Интервал в формате [a,b) (a,b - целое число)
#
#  Примеры соответствия шаблону
#
# [1,5), [0,10), [0,0), [-1,5)

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Verum ab Histro oppida Cremniscoe, Aepolium, montes Macrocremni, clarus amnis Tyra, oppido nomen inponens ubi antea Ophiusa dicebatur. in eodem insulam spatiosam inclutn Tyragetae; abest a Pseudostomo Histri ostio CXXX. mox Axiacae cognomines flumini, ultra quos Crobyzi, flumen Rhode, sinus Saggarius, portus Ordesos et a Tyra CXX flumen Borysthenes lacusque et gens eodem nomine et oppidum ab mari recedens XV passuum, Olbiopolis et Miletopolis antiquis nominibus. 83 rursus litore portus Achaeorum, insula Achillis, tumulo eius viri clara, et ab ea CXXV passuum paeninsula ad formam gladii in transversum porrecta, exercitatione eiusdem cognominata Dromos Achilleos, cuius longitudinem LXXX tradidit Agrippa. totum eum tractum tenent Sardi Scythae et Siraci. inde silvestris regio Hylaeo mare, quo adluitur, cognominavit; Enoaecadioe vocantur incolae. ultra Panticapes amnes, qui Nomadas et Georgos disterminat, mos Acesinus. quidam Panticapen confluere intra Olbiam cum Borysthene tradunt, diligentiores Hypanim, tanto errore eorum, qui illum in Asiae parte prodidere.
#
# Mare subit magno recessu, donec V passuum intervallo absit a Maeotide, vasta ambiens spatia multasque gentes. sinus Carcinites appellatur. flumen Pacyris; oppida Navarum, Carcine. a tergo lacus Buces, fossa emissus in mare. ipse Buces a Coreto, Maeoti lacus sinu, petroso discluditur dorso. recipit amnes Bucem, Gerrhum. Hypanim, ex diverso venientes tractu. nam Gerrhus Basilidas et Nomadas separat, Hypanis per Nomadas et Hylaeos fluit, manu facto alveo in Bucen, naturali in Coretum. regio Scythiae Sindica nominatur.

# %% [markdown]
# Шаблон для поиска: слова длиной от 3 до 5 символов, начинающиеся на букву d
#
#  Примеры соответствия шаблону
#
# donec

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате CSV:
#
# email;password;phone
# - email – адрес электронной почты:
# - должен содержать имя пользователя, @ и домен. Например, username@site.ru. Корректным именем пользователя считаются только символы английского алфавита в любом регистре, цифры длиной от 1 до 30 символов. Корректным именем домена считаются только символы английского алфавита в любом регистре, цифры длиной от 1 до 30 символов.;
# - домен должен быть из зоны ru (например, mail.ru, yandex.ru);
# - password – пароль:
# - длина от 8 до 20 символов включительно;
# - должен содержать хотя бы одну цифру и хотя бы одну заглавную букву английского алфавита. Можно использовать символы английского алфавита, цифры, специальные символы не допускаются;
# - phone – номер телефона:
# - должен начинаться с + и содержать только цифры;
# - длина номера должна быть от 10 до 15 символов.
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# user@mail.ru;Password123;+79123456789

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Observer
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Новостной портал: Когда публикуется новость, все подписчики (email, мессенджер,
# мобильное приложение) должны получать уведомление. Реализуйте систему подписки.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Liskov Substitution Principle (LSP) — Принцип подстановки Барбары Лисков: Объекты в программе должны быть заменяемыми на экземпляры их подтипов без изменения корректности выполнения программы.

# %%
class Vehicle:
    """A demo Vehicle class"""

    def __init__(self, name: str, speed: float):
        self.name = name
        self.speed = speed

    def get_name(self) -> str:
        """Get vehicle name"""
        return f"The vehicle name {self.name}"

    def get_speed(self) -> str:
        """Get vehicle speed"""
        return f"The vehicle speed {self.speed}"

    def engine(self):
        """A vehicle engine"""
        pass

    def start_engine(self):
        """A vehicle engine start"""
        self.engine()


class Car(Vehicle):
    """A demo Car Vehicle class"""

    def start_engine(self):
        pass


class Bicycle(Vehicle):
    """A demo Bicycle Vehicle class"""

    def start_engine(self):
        pass

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
