# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Научный формат ?###0E+00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +250E+30, 0E-30, -51E+00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: IPv4 адрес: XXX.XXX.XXX.XXX (0-255)
#
#  Примеры соответствия шаблону
#
# 192.168.0.1, 255.255.255.0, 8.8.8.8

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Aquitanicae sunt Ambilatri, Anagnutes, Pictones, Santoni liberi, Bituriges liberi cognomine Vivisci, Aquitani, unde nomen provinciae, Sediboviates. mox in oppidum contributi Convenae, Begerri, Tarbelli Quattrosignani, Cocosates Sexsignani, Venami, Onobrisates, Belendi, saltus Pyrenaeus infraque Monesi, Oscidates Montani, Sybillates, Camponi, Bercorcates, Pinpedunni, Lassunni, Vellates, Toruates, Consoranni, Ausci, Elusates, Sottiates, Oscidates Campestres, Succasses, Latusates, Basaboiates, Vassei, Sennates, Cambolectri Agessinates. 109 Pictonibus iuncti autem Bituriges liberi qui Cubi appellantur, dein Lemovices, Arverni liberi, Vellavi liberi, Gabales. rursus Narbonensi provinciae contermini Ruteni, Cadurci, Nitiobriges Tarneque amne discreti a Tolosanis Petrocori.
#
# Maria circa oram ad Rhenum septentrionalis oceanus. inter Rhenum et Sequanam Britannicus, inter id et Pyrenaeum Gallicus. insulae conplures Venestorum et quae Veneticae appellantur et in Aquitanico sinu Vliaros.

# %% [markdown]
# Шаблон для поиска: слова, содержащие три символа a, через один символ
#
#  Примеры соответствия шаблону
#
# abacada

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате JSON:
#
#
# {“message”:”messageID”, “parent”:”parentID”, “text”:”text”}
#
# - messageID – это ID сообщения, целое число от 1000 до 9999 включительно;
# - parentID – это ID родительского сообщения, целое число от 1000 до 9999 включительно, если сообщение является началом цепочки, то parentID=0;
# - text  – это содержание сообщения, набор символов английского алфавита длиной от 1 до 100 включительно.
#
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# {"message":1000,"parent":0,"text":"Hello"}
#
#
# {"message":1001,"parent":1000,"text":"Hi there"}
#
#
# {"message":1002,"parent":1001,"text":"How are you?"}

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Strategy
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Система сортировки: Данные можно сортировать разными алгоритмами
# (пузырьком, быстрая, слиянием). Пользователь выбирает алгоритм во время выполнения.
# Реализуйте стратегии сортировки.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Dependency Inversion Principle (DIP) — Принцип инверсии зависимостей: Модули верхних уровней не должны зависеть от модулей нижних уровней; оба должны зависеть от абстракций (интерфейсов). Абстракции не должны зависеть от деталей, а детали — от абстракций.

# %%
from abc import ABC, abstractmethod

class DiskStorage:
    def save(self, data):
        print(f"Saving data to disk: {data}")

class DataStorer:
    def __init__(self):
        self.storage = FiskStorage()

    def store(self, data):
        self.storage.save(data)


data_storer = DataStorer()
data_storer.store("Disk storage data")

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
