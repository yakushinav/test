# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Вещественное число в формате +#,00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +12,456, -,30, +0,60

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Время в формате ЧЧ:ММ AM/PM
#
#  Примеры соответствия шаблону
#
# 02:30 PM, 09:15 AM, 11:45 PM

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Achaiae nomen provinciae ab Isthmo incipit. antea Aegialos vocabatur propter urbes in litore per ordinem dispositas. primae ibi quas diximus Lecheae, Corinthiorum portus, mox Olyros, Pellenaeorum castellum, oppida Helice, Bura, in quae refugere haustis prioribus, Sicyon, Aegira, Aegium, Erineos. intus Cleonae, Hysiae. 13 Panhormus portus demonstratumque iam Rhium, a quo promunturio V absunt Patrae, quas supra memoravimus. locus Pherae. in Achaia novem montium Scioessa notissimus, fons Cymothoe. ultra Patras oppidum Olenum, cox Dyme, loca Buprasium, Hyrmine, promunturium Araxus, Cyllenius sinus, promunturium Chelonates, unde Cyllenen XV p., castellum Phlius, quae regio ab Homero Araethyrea dicta est, postea Asopis. 14 inde Eliorum ager, qui antea Epioe vocabantur. ipsa Elis in mediterraneo et a Pylo XIII intus delubrum Olympii Iovis, ludorum claritate fastos Graeciae complexum, Pisaeorum quondam oppidum, praefluente Alpheo amne. at in ora promunturium Ichthys, amnis Alpheus — navigatur VI p. —, oppida Aulon, Leprium, promunturium Platanodes. omnia haec ad occasum versa, 15 ad meridiem Cyparissius sinus cum urbe Cyparisso LXXV circuitu, oppida Pylos, Mothone, locus Helos, promunturium Acritas, sinus Asinaeus ab oppido Asine, Coronaeus a Corone. finiuntur Taenaro promunturio. ibi regio Messenia duodeviginti montium, amnis Pamisus, intus autem ipsa Messene, Ithome, Oechalia, Arene, Pteleon, Thryon, Dorion, Zancle, variis quaeque clara temporibus. huius sinus circuitus LXXX, traiectus vero XXX.

# %% [markdown]
# Шаблон для поиска: слова, содержащие три символа k
#
#  Примеры соответствия шаблону
#
# kakistok

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# Корректный запрос имеет формат CSV:
#
# serviceID;code;data
# - поле serviceID непустое и содержит идентификатор микросервиса целое число от 100 до 999 включительно;
# - поле code непустое содержит код операции, три символа английского алфавита в верхнем регистре;
# - поле data непустое и содержит символы английского алфавита в любом регистре, пробелы спецсимволы и знаки препинания, длина поля от 3 до 100 символов.
#
# Пробелы в начале, в конце и внутри строки с запросом допускаются.

# %% [markdown]
# Примеры входных данных
#
#
# 100;ABC;Hello world
#
# 101;XYZ;<script>alert('XSS')</script>
#
# 102;DEF;Normal data SELECT * FROM users
#
# 103;GHI;<script>alert('XSS')</script> data with UPDATE in middle

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Adapter
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Медиаплеер: Новый плеер поддерживает только форматы MP3 и AAC, но нужно
# воспроизводить старые форматы (WAV, OGG) через специальные декодеры.
# Создайте адаптер для поддержки legacy-форматов.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Open/Closed Principle (OCP) — Принцип открытости/закрытости: Программные сущности должны быть открыты для расширения, но закрыты для модификации. Это значит, что можно добавлять новую функциональность, не меняя существующий код.

# %%
class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

def total_area(shapes):
    return sum(shape.area() for shape in shapes)

shapes = [Circle(5), Rectangle(4, 5)]
print(total_area(shapes))

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
