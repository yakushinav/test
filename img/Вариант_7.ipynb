# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Вещественное число в формате +0.00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +12.456, -0.30, +6.00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Дата в формате ДД.ММ.ГГГГ
#
#  Примеры соответствия шаблону
#
# 31.12.2023, 01.01.2000, 15.08.2025

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Baetica, a flumine mediam secante cognominata, cunctas provinciarum diviti cultu et quodam fertili ac peculiari nitore praecedit. iuridici conventus ei IIII, Gaditanus, Cordubensis, Astigitanus, Hispalensis. oppida omnia numero CLXXV, in iis coloniae VIIII, municipia c. R. X, Latio antiquitus donata XXVII, libertate VI, foedere III, stipendiaria CXX. ex his digna memoratu aut Latio sermone dictu facilia, a flumine Ana litore oceani oppidum Ossonoba, Aestuaria cognominatum, inter confluentes Luxiam et Urium, Hareni montes, Baetis fluvius, litus Curense inflexo sinu, cuius ex adverso Gadis inter insulas dicenda, promunturium Iunonis, portus Baesippo, oppidum Baelo, Mellaria, fretum ex Atlantico mari, Carteia, Tartesos a Graecis dicta, mons Calpe.
#
# dein litore interno oppida Barbesula cum fluvio, item Salduba, oppidum Suel, Malaca cum fluvio foederatorum. dein Maenuba cum fluvio, Sexi cognomine Firmum Iulium, Sel, Abdara, Murgi, Baeticae finis. oram eam in universum originis Poenorum existimavit M. Agrippa; ab Ana autem Atlantico oceano obversa Bastulorum Turdulorumque est. in universam Hispaniam M. Varro pervenisse Hiberos et Persas et Phoenicas Celtasque et Poenos tradit. lusum enim Liberi patris aut lyssam cum eo bacchantium nomen dedisse Lusitaniae et Pana praefectum eius universae. at quae de Hercule ac Pyrene vel Saturno traduntur fabulosa in primis arbitror.

# %% [markdown]
# Шаблон для поиска: слова длиной 5 символов, заканчивающиеся на букву a
#
#  Примеры соответствия шаблону
#
# nulla

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате:
#
#
# system;token;clientID;sum
# - system это одна из двух платежных систем F для First и S для Second
# - token это одноразовый платежный токен, набор цифр и символов английского алфавита в нижнем регистре длиной 7 символов
# - clientID это ID клиента, целое число от 1000 до 9999 включительно
# - sum это сумма платежа, целое число от 1000 до 1000000 включительно
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# S;aaaaaaa;1234;1000000
#
# F;bbbbbbb;5678;500000
#
# S;ccccccc;9012;250000
#
# F;ddddddd;3456;75000

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Abstract Factory
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Игровые миры: Разные тематики миров (фэнтези, научная фантастика, постапокалипсис).
# Каждый мир имеет уникальных персонажей, оружие и транспорт, которые должны быть стилистически совместимы.
# Реализуйте абстрактную фабрику для создания объектов игрового мира.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
class Book:
    inventory = []
    
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.add_to_inventory()
        
    def add_to_inventory(self):
        self.inventory.append(self)
        
    def remove_from_inventory(self):
        self.inventory.remove(self)

book1 = Book("1984", "George Orwell")
book2 = Book("To Kill a Mockingbird", "Harper Lee")

library = Library()
library.add_book(book1)
library.add_book(book2)

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
