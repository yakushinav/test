# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Целое число в формате +#####0
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +123456, -123, +6

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Электронная почта: local.part@domain.zone (латинские буквы, цифры, точки, дефисы), zone может принимать значение ru, edu, ret
#
#  Примеры соответствия шаблону
#
# test.user@example.com, john.doe@company.edu, info.info@site-123.ret

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Primum ergo de Europa, altrice victoris omnium gentium populi longeque terrarum pulcherrima, quam plerique merito non tertiam portionem fecere, verum aequam, in duas partes ab amne Tanai ad Gaditanum fretum universo orbe diviso. oceanus a quo dictum est spatio Atlanticum mare infundens et avido meatu terras, quaecunque venientem expavere, demergens resistentes quoque flexuoso litorum anfractu lambit, Europam vel maxime recessibus crebris excavans, sed in quattuor praecipuos sinus, quorum primus a Calpe Hispaniae extimo, ut dictum est, monte Locros, Bruttium usque promunturium, inmenso ambitu flectitur.
#
# In eo prima Hispania terrarum est, ulterior appellata, eadem Baetica, mox a fine Murgitano citerior eademque Tarraconensis ad Pyrenaei iuga. ulterior in duas per longitudinem provincias dividitur, si quidem Baeticae latere septentrionali praetenditur Lusitania, amne Ana discreta. ortus hic in Laminitano agro citerioris Hispaniae et modo in stagna se fundens, modo in angustias resorbens aut in totum cuniculis condens et saepius nasci gaudens in Atlanticum oceanum effunditur. Tarraconensis autem, adfixa Pyrenaeo totoque eius a latere decurrens et simul ad Gallicum oceanum Hiberico a mari transversa se pandens, Solorio monte et Oretanis iugis Carpetanisque et Asturum a Baetica atque Lusitania distinguitur.

# %% [markdown]
# Шаблон для поиска: слова длиной 7 символов, начинающиеся на букву d
#
#  Примеры соответствия шаблону
#
# dolores

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате:
#
#
#
# personID;daysOfWork;baseSummPerDay;newClients;SalesPlan;SalesFact
# - personID – это ID сотрудника, целое число от 1000 до 9999 включительно;
# - daysOfWork это количество отработанных дней, целое число от 1 до 31 включительно;
# - baseSummPerDay – это базовая сумма за день, целое число от 1000 до 10000 включительно;
# - newClients – это количество новых клиентов, целое число от 0 до 100 включительно;
# - SalesPlan – это план по продажам, целое число от 50000 до 1000000 включительно;
# - SalesFact – это фактическая сумма продаж, целое число от 0 до 10000000 включительно.
#
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# 2001; 22; 1800; 5; 150000; 180000
#
#
# 2002; 18; 2200; 1; 90000; 0
#
#
# 2003; 25; 2500; 0; 200000; 10000

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Abstract Factory
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Мебельный магазин: Производство комплектов мебели в разных стилях
# (классика, модерн, лофт). Каждый стиль включает совместимые стул, стол и шкаф.
# Создайте абстрактную фабрику для производства гарнитуров.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
class TelephoneDirectory:
  def __init__(self):
    self.telephonedirectory = {}

  def add_entry(self, name, number):
    self.telephonedirectory[name] = number

  def delete_entry(self, name):
    self.telephonedirectory.pop(name)

  def update_entry(self, name, number):
    self.telephonedirectory[name] = number

  def lookup_number(self, name):
    return self.telephonedirectory[name]
 
  def save_to_file(self, file_name, location):
    #code to save the contents of telephonedirectory dictionary to the file
    pass

  def persist_to_database(self, database_details):
    #code to persist the contents of telephonedirectory dictionary to database
    pass

  def __str__(self):
    ret_dct = ""
    for key, value in self.telephonedirectory.items():
      ret_dct += f'{key} : {value}\n'
    return ret_dct

myTelephoneDirectory = TelephoneDirectory()
myTelephoneDirectory.add_entry("Ravi", 123456)
myTelephoneDirectory.add_entry("Vikas", 678452)
print(myTelephoneDirectory)

myTelephoneDirectory.delete_entry("Ravi")
myTelephoneDirectory.add_entry("Ravi", 123456)
myTelephoneDirectory.update_entry("Vikas", 776589)
print(myTelephoneDirectory.lookup_number("Vikas"))
print(myTelephoneDirectory)

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
