# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Веб-цвета — цвета, используемые при отображении веб-страниц, в виде #HHHHHH, где H это шестнадцатеричная цифра
#
#  Примеры соответствия шаблону
#
# #123ABC, #AABBCC, #00ffff

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: IPv6 адрес: 8 групп по 4 шестнадцатеричных цифр
#
#  Примеры соответствия шаблону
#
# 2001:0db8:85a3:0000:0000:8a2e:0370:7334, fe80::1, ::1

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# A Pyrenaei promunturio Hispania incipit, angustior non Gallia modo, verum etiam semet ipsa, ut diximus, inmesnum quantum hinc oceano, illinc Hiberico mari comprimentibus. ipsa Pyrenaei iuga ab exortu aequinoctiali in occasum brumalem breviores quam latere meridiano Hispanias faciunt. proxima ora citerioris est eiusdemque Tarraconensis situs. a Pyrenaeo per oceanum Vasconum saltus, Olarso, Vardulorum oppida, Morogi, Menosca, Vesperies, Amanum portus, ubi nunc Flaviobrica colonia. 111 civitatium novem regio Cantabrorum. flumen Sauga. portus Victoriae Iuliobrigensium; ab eo loco fontes Hiberi XL p. portus Blendium. Orgenomesci e Cantabris; portus eorum Veseiasueca. regio Asturum, Noega oppidum. in paeninsula Paesici et deinde conventus Lucensis a flumine Navia Albiones, Cibarci, Egi, Varri cognomine Namarini, Adovi, Arroni, Arrotrebae. promunturium Celticum, amnes Florius, Nelo. Celtici cognomine Neri et super Tamarci, quorum in paeninsula tres area Sestianae Augusto dicatae, Copori, oppidum Noeta, Celtici cognomine Praestamarci, Cileni. ex insulis nominandae Corticata et Aunios. 112 a Cilenis conventus Bracarum Helleni, Grovi, castellum Tyde, Graecorum subolis omnia. iae Siccae, oppidum Abobrica. Minius amnis, IIII ore spatiosus, Leuni, Surbi, Bracarum oppidum Augusta, quos super Gallaecis flumen Limia, Durius amnis e maximis Hispaniae, ortus in Pelendonibus et iuxta Numantiam lapsus, dein per Arevacos Vaccaeosque, disterminatis ab Asturia Vettonibus, a Lusitania Gallaecis, ibi quoque Turdulos a Bracaris arcens. omnis, quae dicta regio a Pyrenaeo, metallis referta auri, argenti, ferri, plumbi nigri albique.

# %% [markdown]
# Шаблон для поиска: слова, содержащие два символа s, через два символа
#
#  Примеры соответствия шаблону
#
# asnbs

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате XML:
# <object unit="unitID" parent="parentID" />
#
# - unitID – это ID юнита, целое число от 1000 до 9999 включительно;
# - parentID – это ID родительского юнита, целое число от 1000 до 9999 включительно. Если юнит одиночный или содержит в себе другие юниты parentID=0.
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# <object unit="1001" parent="0"/>
#
# <object unit="1002" parent="1001"  />
#
# <object unit="1003" parent="1001"/>

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Strategy
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Оплата заказа: Пользователь может выбрать способ оплаты
# (кредитная карта, PayPal, наличные). Каждый способ имеет свою логику обработки.
# Реализуйте стратегии оплаты.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Dependency Inversion Principle (DIP) — Принцип инверсии зависимостей: Модули верхних уровней не должны зависеть от модулей нижних уровней; оба должны зависеть от абстракций (интерфейсов). Абстракции не должны зависеть от деталей, а детали — от абстракций.

# %%
import typing
from dataclasses import dataclass

class ComicBook:
    def __init__(self, title: str, pages: int, content: str) -> None:
        self.title = title
        self.pages = pages
        self.content = content


class Stamper:
    def __init__(self) -> None:
        self.label = "10th anniversary label"

    def stamp(self, book: ComicBook) -> None:
        print(f"Stamping: {book.title} with: {self.label}")


class Shipper:
    def __init__(self) -> None:
        self.stamper = Stamper()

    def ship_it(self, book: ComicBook) -> None:
        self.stamper.stamp(book)
        print(f"Shipping: {book.title} to the customer..")

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
