# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Научный формат +###0E+00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +250E+30, -0E-30, -51E+00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Интервал в формате {a,b} (a,b - целое число)
#
#  Примеры соответствия шаблону
#
# {1,5}, {0,10}, {0,0}, {-1,5}

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Ex adverso huius situs Britannia insula, clara Graecis nostrisque monimentis, inter septentrionem et occidentem iacet, Germaniae, Galliae, Hispaniae, multo maximis Europae partibus, magno intervallo adversa. Albion ipsi nomen fuit, cum Britanniae vocarentur omnes de quibus mox paulo dicemus. haec abest a Gesoriaco Morinorum gentis litore proximo traiectu L. circuitu patere |XXXXVIII|:LXXV Pytheas et Isidorus tradunt, XXX prope iam annis notitiam eius Romanis armis non ultra vicinitatem silvae Calidoniae propagantibus. Agrippa longitudinem DCCC esse, latitudinem CCC credit, eandem Hiberniae, sed longitudinem CC minorem. 103 super eam haec sita abest brevissimo transitu a Silurum gente XXX. reliquarum nulla CXXV amplior circuitu proditur. sunt autem XL Orcades, modicis inter se discretae spatiis, VII Haemodae, XXX Hebudes et inter Hiberniam ac Britanniam Mona, Monapia, Riginia, Vectis, Silumnus, Andros, infra vero Samnis et Axanthos et ab adversa in Germanicum mare sparsae Glaesiae, quas Electridas Graeci recentiores appellavere, quod ibi electrum nasceretur. 104 ultima omnium quae memorantur Tyle, in qua solstitio nullas esse noctes indicavimus, cancri signum sole transeunte, nullosque contra per brumam dies. hoc quidam senis mensibus continuis fieri arbitrantur. Timaeus historicus a Britannia introrsus sex dierum navigatione abesse dicit insulam Ictim, in qua candidum plumbum proveniat; ad eam Britannos vitilibus navigiis corio circumsutis navigare. a Tyle unius diei navigatione mare concretum a nonnullis Cronium appellatur.

# %% [markdown]
# Шаблон для поиска: слова длиной 5 или 7 символов, заканчивающиеся на букву o
#
#  Примеры соответствия шаблону
#
# proximo

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# Система обработки платежей клиентов генерирует записи логов в следующем формате:
#
# [ГГГГ-ММ-ДД ЧЧ:ММ:СС] CODE: Message (user_id=5821; amount=1500; error=C023)
# - CODE – это вид записи лога одно из трех значений: INFO, ERROR, WARNING;
# - Message – пояснительное сообщение набор символов английского алфавита и пробелов длиной от 5 до 30 символов;
# - user_id – это идентификатор клиента, целое число от 1000 до 9999 включительно;
# - amount – это сумма платежа, целое число от 1 до 1000000 включительно;
# - error – это код ошибки, имеющий следующий формат XNNN, X это один из символов F,C,A, NNN это число от 000 до 999 включительно.
# На вход подаются строки в следующем формате:
# [ГГГГ-ММ-ДД ЧЧ:ММ:СС] CODE: Message (user_id=5821; amount=1500; error=C023)
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# [2023-01-15 10:30:45] ERROR: Payment processing failed (user_id=5821; amount=1500; error=C023)
#
# [2023-01-15 10:31:22] INFO: Payment processed successfully (user_id=1234; amount=500; error=A000)
#
# [2023-01-15 10:32:10] ERROR: Invalid user details (user_id=9999; amount=100; error=F404)

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Strategy
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Навигатор: Маршрут можно строить разными способами (пеший, на автомобиле,
# общественный транспорт). Алгоритмы расчета разные, но интерфейс один.
# Реализуйте стратегии для построения маршрутов.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Interface Segregation Principle (ISP) — Принцип разделения интерфейсов: Клиент не должен зависеть от интерфейсов, которые он не использует. Лучше иметь много маленьких интерфейсов, чем один большой 'жирный'.

# %%
class Shape:
    """A demo shape class"""

    def draw_circle(self):
        """Draw a circle"""
        raise NotImplemented

    def draw_square(self):
        """ Draw a square"""
        raise NotImplemented


class Circle(Shape):
    """A demo circle class"""


def draw_circle(self):
    """Draw a circle"""
    pass


def draw_square(self):
    """ Draw a square"""
    pass

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
