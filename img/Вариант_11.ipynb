# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Вещественное число в формате ?0,00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +12,456, -0,30, 6,00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Время в формате ЧЧ:ММ:СС
#
#  Примеры соответствия шаблону
#
# 14:30:25, 09:15:00, 23:59:59

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Peloponnesus, Apia antea appellata et Pelasgia, paeninsula haut ulli terrae nobilitate postferenda, inter duo maria Aegeum et Ionium, platani folio similis propter angulosos recessus, circuitu DLXIII p. colligit auctore Isidoro; eadem per sinus paene tantundem adicit. angustiae, unde procedit, Isthmos appellatur. in eo loca inrumpentia e diverso quae dicta sunt maria a septentrione et exortu eius omnem ibi latitudinem vorant, donec contrario incursu tantorum aequorum V milium passuum intervallo exesis utrimque lateribus angusta cervice Peloponnesum contineat Hellas. 10 Corinthiacus hinc, illinc Caronicus appellatur sinus; Lecheae hinc, Cenchreae illinc angustiarum termini, longo et ancipiti navium ambitu quas magnitudo plaustris transvehi prohibet. quam ob causam perfodere navigabili alveo angustias eas temptavere Demeterius rex, dictator Caesar, Gaius princeps, Domitius Nero, nefasto, ut omnium exitu patuit, incepto. 11 in medio hoc intervallo, quod Isthmon appellavimus, adplicata colli habitatur colonia Corinthus, antea Ephyra dicta, sexagenis ab utroque litore stadiis, e summa sua arce, quae vocatur Acrocorinthos, in qua fons Pirene, diversa duo maria prospectans. LXXXVIII p. ad Corinthiacum sinum traiectus est Patras a Leucade. Patrae, colonia in longissimo promunturio Peloponnesi ut dictum est, intervallo in ipsis faucibus, sinum Corinthiacum LXXXV in longitudinem usque ad Isthmon transmittunt.

# %% [markdown]
# Шаблон для поиска: слова, содержащие два символа s
#
#  Примеры соответствия шаблону
#
# possimus

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# Строки, содержащие запросы в формате CSV:
#
# userID,time,query
# - поле userID непустое и содержит идентификатор пользователя целое число от 10000 до 99999 включительно;
# - поле time непустое содержит временную метку в формате ЧЧ:ММ:СС;
# - поле query непустое и содержит хотя бы три подряд идущих символа английского алфавита в любом регистре, длина поля от 3 до 100 символов.
#
# Могут быть пробелы в начале, в конце и внутри строки с запросом

# %% [markdown]
# Примеры входных данных
#
#
# 10001,12:30:45,search for plants
#
# 10002,13:45:00,SELECT * FROM users
#
# 99999,23:59:59,<script>alert('xss')</script>
#
# 1234,25:00:00,invalid time

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Adapter
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Платежные системы: Ваше приложение работает с платежным интерфейсом `processPayment()`,
# но нужно подключить старую систему, которая использует метод `makeTransaction()`.
# Создайте адаптер для совместимости.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Open/Closed Principle (OCP) — Принцип открытости/закрытости: Программные сущности должны быть открыты для расширения, но закрыты для модификации. Это значит, что можно добавлять новую функциональность, не меняя существующий код.

# %%
class BadCar:
    def __init__(self, type):
        self.type = type

    def can_fly(self):
        # When a new car type is added, we need to change this method
        if self.type == "regular":
            return False
        elif self.type == "flying":
            return True
        # New type added, we need to change this method
        return False


print("BAD EXAMPLE - OCP Violation:")
bad_regular_car = BadCar("regular")
bad_flying_car = BadCar("flying")
print(f"Regular car can fly: {bad_regular_car.can_fly()}")
print(f"Flying car can fly: {bad_flying_car.can_fly()}")
print("To add a new car type, we need to change the BadCar class!")

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
