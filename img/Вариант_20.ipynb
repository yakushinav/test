# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Научный формат ?##00E+00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +250E+30, 50E-30, -1251E+00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Интервал в формате <a,b> (a,b - целое число)
#
#  Примеры соответствия шаблону
#
# <1,5>, <0,10>, <0,0>, <-1,5>

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Toto autem mari ad Scaldim usque fluvium Germaniae accolunt gentes, haud explicabili mesnura: tam inmodica prodentium discordia est. Graeci et quidam nostri |XXV| oram Germaniae tradiderunt, Agrippa cum Raetia et Norico longitudinem DCXXXVI, latitudinem CCXLVIII, 99 si coniectare permittitur, haut multum ora deerit Graecorum opinioni et longitudini ab Agrippa proditae. Germanorum genera quinque: Vandili, quorum pars Burgodiones, Varinnae, Charini, Gutones. alterum genus Inguaeones, quorum pars Cimbri, Teutoni ac Chaucorum gentes. 100 proximi autem Rheno Istuaeones, quorum ..... mediterranei Hermiones, quorum Suebi, Hermunduri, Chatti, Cherusci. quinta pars Peucini, Basternae, supra dictis contermini Dacis. amnes clari in oceanum defluunt Guthalus, Visculus sive Vistla, Albis, Visurgis, Amisis, Rhenus, Mosa. introrsus vero nullo inferius nobilitate Hercynium iugum praetenditur. 101 in Rheno autem ipso, prope C in longitudinem, nobilissima Batavorum insula et Cannenefatium et aliae Frisiorum, Chaucorum, Frisiavonum, Sturiorum, Marsaciorum, quae sternuntur inter Helinium ac Flevum. ita appellantur ostia, in quae effusus Rhenus a septentrione in lacus, ab occidente in amnem Mosam se spargit, medio inter haec ore modicum nomini suo custodiens alveum

# %% [markdown]
# Шаблон для поиска: слова длиной меньше 6 символов, заканчивающиеся на букву f
#
#  Примеры соответствия шаблону
#
# nisf

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# Логи передаются в формате XML:
#
#
# <worker ip=”workerIP” email=”workerEmail” timestamp=”timestamp”> message </worker>
#
# - ip – это IPv4 адрес сотрудника;
# - email – корпоративный адрес электронной почты;
# - timestamp – временная метка в формате ЧЧ:ММ:ДД:ММ:ГГГГ;
# - message – это информационное сообщение, набор символов английского алфавита и пробелов длиной от 2 до 30 включительно.
#
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# <worker ip="256.0.0.1" email="invalid_email" timestamp="99:99:99:99:9999">Invalid data</worker>
#
#
# <worker ip="192.168.1.1" email="johndoe@company.org" timestamp="12:30:15:04:2023">System started</worker>
#
#
# <worker ip="400.168.1.1" email="johndoe@company.org" timestamp="12:30:15:04:2023">System started</worker>

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Observer
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Система складского учета: При изменении количества товара на складе
# нужно уведомлять отделы закупок, продаж и логистики. Реализуйте наблюдателей
# для отслеживания изменений.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Interface Segregation Principle (ISP) — Принцип разделения интерфейсов: Клиент не должен зависеть от интерфейсов, которые он не использует. Лучше иметь много маленьких интерфейсов, чем один большой 'жирный'.

# %%
from abc import ABCMeta, abstractmethod

class CommunicationDevice():
  @abstractmethod
  def make_calls():
    pass

  @abstractmethod
  def send_sms():
    pass

  @abstractmethod
  def browse_internet():
    pass

class SmartPhone(CommunicationDevice):
  def make_calls():
    #implementation
    pass

  def send_sms():
    #implementation
    pass

  def browse_internet():
    #implementation
    pass

  class LandlinePhone(CommunicationDevice):
    def make_calls():
      #implementation
      pass

    def send_sms():
      #just pass or raise exception as this feature is not supported 
      pass

    def browse_internet():
      #just pass or raise exception as this feature is not supported
      pass

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
