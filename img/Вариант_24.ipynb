# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Символ в кодировке UNICODE: U+####
#
#  Примеры соответствия шаблону
#
# U+0041, U+1141, U+0541

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: MAC адрес: XX:XX:XX:XX:XX:XX (шестнадцатеричные цифры)
#
#  Примеры соответствия шаблону
#
# 00:1A:2B:3C:4D:5E, AA:BB:CC:DD:EE:FF, 01-23-45-67-89-AB

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Universa provincia dividitur in conventus tres, Emeritensem, Pacensem, Scalabitanum, tota populorum XLV, in quibus coloniae sunt quinque, municipium civium Romanorum, Latii antiqui III, stipendiaria XXXVI. coloniae Augusta Emerita, Anae fluvio adposita, Metellinensis, Pacensis, Norbensis Caesarina cognomine; contributa sunt in eam Castra Servilia, Castra Caecilia. qunita est Scalabis quae Praesidium Iulium vocatur. municipium civium Romanorum Olisipo, Felicitas Iulia cognominatum. oppida veteris Latii Ebora, quod item Liberalitas Iulia, et Myrtilis ac Salacia, quae dixmu. 118 stipendiariorum quos nominare non pigeat, praeter iam dictos in Baeticae cognominibus, Augustobrigenses, Aeminienses, Aranditani, Arabricenses, Balsenses, Caesarobrigenses, Caperenses, Caurienses, Colarni, Cibilitani, Cocnordienses, Elbocori, Interannienses, Lancienses, Mirobrigenses qui Celtici cognominantur, Medubrigenses qui Plumbari, Ocelenses, Turduli qui Bardili et Tapori.
#
# Lusitaniam cum Asturia et Gallaecia patere longitudine DXL, latitudine DXXXVI, Agrippa prodidit. omnes autem Hispaniae a duobus Pyrenaei promunturiis per maria totius orae circuitu |XXVIIII|:XXIIII colligere existimantur, ab aliis |XXVI|.

# %% [markdown]
# Шаблон для поиска: слова, содержащие два символа d, через три символа
#
#  Примеры соответствия шаблону
#
# dividitur

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подаются строки в следующем формате:
# [ДД:ММ:ГГГГ] - Price
#
# Price – вещественное число от 1 до 10000 включительно, содержащее два знака после запятой. Целая часть отделяется точкой. Если дробная часть не имеет значащих цифр, указывается 00.
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# [01:01:2023] - 100.50
#
# [15:01:2023] - 105.75
#
# [03:02:2023] - 95.25
#
# [20:02:2023] - 97.50

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Strategy
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Генератор отчетов: Отчеты можно выводить в разных форматах
# (текстовый, графический, табличный). Алгоритмы генерации разные.
# Реализуйте стратегии для создания отчетов.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Dependency Inversion Principle (DIP) — Принцип инверсии зависимостей: Модули верхних уровней не должны зависеть от модулей нижних уровней; оба должны зависеть от абстракций (интерфейсов). Абстракции не должны зависеть от деталей, а детали — от абстракций.

# %%
class BackendDeveloper:
    """This is a low-level module"""

    @staticmethod
    def python():
        print("Writing Python code")


class FrontendDeveloper:
    """This is a low-level module"""

    @staticmethod
    def javascript():
        print("Writing JavaScript code")


class Project:
    """This is a high-level module"""

    def __init__(self):
        self.backend = BackendDeveloper()
        self.frontend = FrontendDeveloper()

    def develop(self):
        self.backend.python()
        self.frontend.javascript()
        return "Develop codebase"


project = Project()
print(project.develop())

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
