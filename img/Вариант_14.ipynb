# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Бухгалтерский формат: добавлен разделитель тысяч ?###,###.00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +1,250.50, 250.50, +1.60

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Время в формате ЧЧ-ММ-СС
#
#  Примеры соответствия шаблону
#
# 14-30-25, 09-15-00, 23-59-59

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# In Thessalia autem Orchomenus, Minyius antea dictus, et oppidum Alimon, ab aliis Holmon, Atrax, Palamna, fons Hyperia, oppida Pherae, quarum a tergo Pieria ad Macedoniam protenditur, Larisa, Gomphi, Thebae Thessalae, nemus Pteleon, sinus Pagasicus, oppidum Pagasa, idem postea Demetrias dictum, Tricca, Pharsali campi cum civitate libera, Crannon, Iletia. montes Phthiotidis Nymphaeus, quod topiario naturae opere spectabilis, Buzygaeus, Conacoessa, Bromiaeus, Daphusa, Chimarone, Athamas, Stephane. 30 in Thessalia quattuor atque triginta, quorum nobilissimi Cercetii, Olympus Pierius, Ossa, cuius ex adverso Pindus et Othrys, Lapitharum sedes, hi ad occasum vergentes, ad ortus Pelious, omnes theatrali modo inflexi, caveatis ante eos LXXV urbibus. flumina Thessaliae Apidamus, Phoenix, Enipeus, Onochonus, Pamisus, fons Messeis, lacus Boebeis et ante cunctos claritate Penius, ortos iuxta Gomphos interque Ossam et Olympum nemorosa convalle defluens D stadiis, dimidio eius spatii navigabilis. 31 in eo cursu Tempe vocant, V passuum longitudine et ferme sesquiugeri latitudine, ultra visum hominis attollentibus se dextra laevaque leniter convexis iugis, intus silva late viridante, ac labitur Penius viridis calculo, amoenus circa ripas gramine, canorus avium concentu. accipit amnem Horcon nec recipiti, sed olei modo supernatantem, ut dictum est Homero, brevi spatio portatum abdicat, poenales aquas dirisque genitas argenteis suis misceri recusans.

# %% [markdown]
# Шаблон для поиска: слова длиной 6 до 9 символов
#
#  Примеры соответствия шаблону
#
# adipisc

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# Корректные данные имеют формат CSV:
#
# itemID;token;message
# - поле itemID непустое и содержит ID товара целое число от 1000 до 9999 включительно;
# - поле token непустое и содержит токен сессии символы английского алфавита в любом регистре, длина поля 12 символов;
# - поле message непустое и содержит символы английского алфавита в любом регистре, пробелы спецсимволы и знаки препинания, длина поля от 3 до 100 символов.
#
# Пробелы в начале, в конце и внутри строки с запросом допускаются.

# %% [markdown]
# Примеры входных данных
#
#
# 1001;ABCDEFGHIJKL;This is a normal comment
#
# 1002;MNOPQRSTUVWX;Please check this <script>alert('xss')</script>
#
# 1003;XYZABCDEFGHI;SELECT * FROM users GRANT ALL PRIVILEGES

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Decorator
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Кофейня: Есть базовый напиток (эспрессо), к которому можно добавлять
# дополнения (молоко, сироп, взбитые сливки). Каждое дополнение меняет стоимость.
# Реализуйте систему декораторов для создания напитков.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Open/Closed Principle (OCP) — Принцип открытости/закрытости: Программные сущности должны быть открыты для расширения, но закрыты для модификации. Это значит, что можно добавлять новую функциональность, не меняя существующий код.

# %%
from enum import Enum
class Products(Enum):
  SHIRT = 1
  TSHIRT = 2
  PANT = 3

class DiscountCalculator():
  def __init__(self, product_type, cost):
    self.product_type = product_type
    self.cost = cost

  def get_discounted_price(self):
    if self.product_type == Products.SHIRT:
      return self.cost - (self.cost * 0.10)
    elif self.product_type == Products.TSHIRT:
      return self.cost - (self.cost * 0.15)
    elif self.product_type == Products.PANT:
      return self.cost - (self.cost * 0.25)

dc_Shirt = DiscountCalculator(Products.SHIRT, 100)
print(dc_Shirt.get_discounted_price())

dc_TShirt = DiscountCalculator(Products.TSHIRT, 100)
print(dc_TShirt.get_discounted_price())

dc_Pant = DiscountCalculator(Products.PANT, 100)
print(dc_Pant.get_discounted_price())

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
