# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Научный формат +##00E+00
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +250E+30, -50E-30, -1251E+00

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Интервал в формате (a,b] (a,b - целое число)
#
#  Примеры соответствия шаблону
#
# (1,5], (0,10], (0,0], (-1,5]

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Exeundum deinde est, ut extera Europae dicantur, transgressisque Ripaeos montes litus oceani septentrionalis in laeva, donec perveniatur Gadis, legendum. insulae complures sine nominibus eo situ traduntur, ex quibus ante Scythiam quae appellatur Baunonia unam abesse diei cursu, in quam veris tempore fluctibus electrum eiciatur, Timaeus prodidit. reliqua litora incerta. signata fama septentrionalis oceani. Amalchium eum Hecataeus appellat a Parapaniso amne, qua Scythiam adluit, quod nomen eius gentis lingua significat congelatum. 95 Philemon Morimarusam a Cimbris vocari, hoc est mortuum mare, inde usque ad promunturium Rusbeas, ultra deinde Cronium. Xenophon Lampsacenus a litore Scytharum tridui navigatione insulam esse inmensae magnitudinis Balciam tradit, eandem Pytheas Basiliam nominat. feruntur et Oeonae, in quibus ovis avium et avenis incolae vivant, aliae, in quibus equinis pedibus homines nascantur, Hippopodes appellati, Phanesiorum aliae, in quibus nuda alioqui corpora praegrandes ipsorum aures tota contegant.
#
# Incipit deinde clarior aperiri fama ab gente Inguaeonum, quae est prima in Germania. mons Saevo ibi, inmensus nec Ripaeis iugis minor, inmanem ad Cimbrorum usque promunturium efficit sinum, qui Codanus vocatur, refertus insulis, quarum clarissima est Scatinavia, inconpertae magnitudinis, portionem tantum eius, quod notum sit, Hillevionum gente quingentis incolente pagis: quare alterum orbem terrarum eam appellant. nec minor est opinione Aeningia. 97 quidam haec habitari ad Vistlam usque fluvium a Sarmatis, Venedis, Sciris, Hirris tradunt, sinum Cylipenum vocari et in ostio eius insulam Latrim, mox alterum sinum Lagnum, conterminum Cimbris. promunturium Cimbrorum excurrens in maria longe paeninsulam efficit, quae Tastris appellatur. XXIII inde insulae Romanis armis cognitae. earum nobilissimae Burcana, Fabaria nostris dicta a frugis multitudine sponte provenientis, item Glaesaria a sucino militiae appellata, barbaris Austeravia, praeterque Actania.

# %% [markdown]
# Шаблон для поиска: слова длиной больше 5 символов, заканчивающиеся на букву a
#
#  Примеры соответствия шаблону
#
# volupta

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате CSV:
#
# orderid;summa;count;gift;express;insurance
# - поле orderid – это ID заказа, целое число от 10000 до 99999 включительно;
# - поле summa – это тип общая сумма заказа, целое число от 100 до 100000 включительно;
# - поле count – это количество товаров в заказе, целое число от 1 до 20 включительно;
# - Поля gift, express, insurance – бинарные. 0 – нет дополнительной услуги, 1 – есть дополнительная услуга.
#
# Допускаются пробелы в начале и конце строки с данными, а также вокруг разделителя полей данных.

# %% [markdown]
# Примеры входных данных
#
#
# 10001;5000;3;1;0;0
#
# 10002;5000;3;0;1;0
#
# 10003;5000;3;0;0;1
#
# 10004;5000;3;1;1;0

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Observer
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
#
# Аукцион: Участники аукциона могут делать ставки. Когда появляется новая ставка,
# все участники должны получать уведомление о текущей максимальной ставке.
# Реализуйте механизм оповещения.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Interface Segregation Principle (ISP) — Принцип разделения интерфейсов: Клиент не должен зависеть от интерфейсов, которые он не использует. Лучше иметь много маленьких интерфейсов, чем один большой 'жирный'.

# %%
from abc import ABC, abstractmethod


class BadKirbyInterface(ABC):
    @abstractmethod
    def be_round(self):
        pass

    @abstractmethod
    def be_cute(self):
        pass

    @abstractmethod
    def turn_into_pink_ball(self):
        pass


class BadBlueKirby(BadKirbyInterface):
    def be_round(self):
        return "I am round"

    def be_cute(self):
        return "I am cute"

    def turn_into_pink_ball(self):
        return "I can't be pink though..."


print("BAD EXAMPLE - ISP Violation:")
blue_kirby = BadBlueKirby()
print(f"Blue Kirby: {blue_kirby.be_round()}")
print(f"Blue Kirby: {blue_kirby.be_cute()}")
print(f"Blue Kirby: {blue_kirby.turn_into_pink_ball()}")
print("Blue Kirby can't turn into a pink ball but has to implement it!")

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
