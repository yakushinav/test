# %% [markdown]
# # Задание 1
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Целое число в формате ?#####0
#
#
# Пояснение для числовых форматов:
# - 0  обязательная цифра
# - \#  необязательная цифра (может отсутствовать)
# - \+  обязательно наличие знака перед числом + или -
# - ?  необязательно наличие знака перед числом + или -
#
#
#  Примеры соответствия шаблону
#
# +123456, -123, 6

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 2
#
#  В этом задании требуется проверить входную строку символов на соответствие шаблону.
#
#  Необходимо написать регулярное выражение и привести 6 примеров (3 соответствует, 3 не соответствует).

# %% [markdown]
# Шаблон: Электронная почта: localpart@domain.zone (латинские буквы, цифры, точки, дефисы), zone может принимать значение org, com, net
#
#  Примеры соответствия шаблону
#
# user@example.com, johndoe@company.co.net, info@site-123.org

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 3
#
#  В этом задании требуется найти в заданном тексте все элементы, соответствующие шаблону.
#
#  Необходимо написать регулярное выражение и вывести на экран требуемые элементы.
#
#  Текст для поиска:
#
#
# Hactenus de situ et miraculis terrae aquarumque et siderum ac ratione universitatis atque mensura. nunc de partibus, quamquam infinitum id quoque existimatur nec temere sine aliqua reprehensione tractatum, haut ullo in genere venia iustiore, si modo minime mirum est hominem genitum non omnia humana novisse. quapropter auctorem neminem unum sequar, sed ut quemque verissimum in quaque parte arbitrabor, quoniam commune ferme omnibus fuit, ut eos quisque diligentissime situs diceret, in quibus ipse prodebat.
#
# ideo nec culpabo aut coarguam quemquam. locorum nuda nomina et quanta dabitur brevitate ponentur, claritate causisque dilatis in suas partes; nunc enim sermo de toto est. quare sic accipi velim, ut si vidua fama sua nomina, qualia fuere primordio ante ullas res gestas, nuncupentur et sit quaedam in his nomenclatura quidem, sed mundi rerumque naturae.

# %% [markdown]
# Шаблон для поиска: слова длиной 6 символов, начинающиеся на букву f
#
#  Примеры соответствия шаблону
#
# fugiat

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 4
#
# Требуется написать функцию, которая выполнит парсинг строки и вернет словарь python, где ключи это имена полей, а значения это значения полей
#
#  Описание входного формата
#
#
# На вход подается набор строк в формате:
#
# <module=”B” date=”dateTime” type=”type”> message
# - B – это признак лога первого модуля;
# - поле date – это дата и время в формате ЧЧ:ММ-ДД:ММ:ГГГГ;
# - type – это одно из значений INFO, WARNING, ERROR;
# - message – это сообщение, набор символов английского алфавита, знаков препинания, пробелов

# %% [markdown]
# Примеры входных данных
#
#
# <module="B" date="14:20-30:06:2024" type="WARNING"> Disk space low
#
# <module="B" date="12:30-01:01:2024" type="ERROR"> Database connection failed

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5
#
# Требуется реализовать паттерн Abstract Factory
#
#  Требуется разработать демонстрационное приложение, моделирующее реализацию паттернов

# %% [markdown]
# Описание:
#
# ""
# UI-библиотека: Создайте кроссплатформенный интерфейс. Для каждой ОС
# (Windows, macOS, Linux) нужны свои стили кнопок, текстовых полей и чекбоксов.
# Реализуйте абстрактную фабрику для создания совместимых компонентов UI.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6
#
#  В этом задании требуется определить в чем состоит нарушение принципа и предложить переработку кода для устранения нарушения
#
# Single Responsibility Principle (SRP) — Принцип единственной ответственности: Класс должен иметь только одну причину для изменения, то есть отвечать только за одну задачу или область ответственности.

# %%
from abc import ABCMeta, abstractmethod

class IEmail(object):
    __metaclass__ = ABCMeta

    @abstractmethod
    def setSender(self, sender):
        pass

    @abstractmethod
    def setReceiver(self, receiver):
        pass

    @abstractmethod
    def setContent(self, content):
        pass

class Email(IEmail):

    def __init__(self, protocol, content_type):
        self.protocol = protocol
        self.content_type = content_type
        self.__sender = None
        self.__receiver = None
        self.__content = None

    def setSender(self, sender):
        if self.protocol == 'IM':
            self.__sender = ''.join(["I'm ", sender])
        else:
            self.__sender = sender

    def setReceiver(self, receiver):
        if self.protocol == 'IM':
            self.__receiver = ''.join(["I'm ", receiver])
        else:
            self.__receiver = receiver

    def setContent(self, content):
        if self.content_type == 'MyML':
            self.__content = '\n'.join(['<myML>', content, '</myML>'])
        else:
            self.__content = content

    def __repr__(self):

        template = "Sender: {sender}\nReceiver: {receiver}\nContent:\n{content}"

        return template.format(sender = self.__sender, receiver = self.__receiver, content = self.__content)

email = Email('IM', 'MyML')
email.setSender('qmal')
email.setReceiver('james')
email.setContent('Hello, there!')
print(email)

# %% [markdown]
# В этой ячейке приведите описание нарушения и основную идею для устранения нарушения
#
#  *ваш текст здесь*

# %%
# Ваш код здесь
